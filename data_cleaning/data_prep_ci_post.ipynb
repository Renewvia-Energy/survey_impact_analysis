# %%
import pandas as pd
import numpy as np
import json
import collections
import re
import category_encoders as ce

# %%
# Importing the commecial dataset
df = pd.read_csv("datasets_annotated/ci_post_annotated.csv", 
                   # usecols=filter_cols
                )
# standardize case
df = df.apply(lambda x: x.astype(str).str.lower())

df["community"] = (df["nigeria_community"].astype(str) + 
                   df["kenya_community"].astype(str)).apply(lambda x: x.replace("nan", ""))
df.head()
# Out:
#   Unnamed: 0                start                  end renewvia_id Column1  \
# 0          0  2022-07-20 04:18:02  2022-07-20 04:24:28      131206     6.0
# 1          1  2022-07-20 04:55:11  2022-07-20 05:01:23      131231     6.0
# 2          2  2022-07-20 05:03:46  2022-07-20 05:12:06      131542     6.0
# 3          3  2022-07-20 05:12:18  2022-07-20 05:42:12      131220     6.0
# 4          4  2022-07-20 05:42:21  2022-07-20 05:47:14      131485     6.0
#
#   country       kenya_community nigeria_community original_person  \
# 0   kenya  kalobeyei settlement               nan             nan
# 1   kenya  kalobeyei settlement               nan             nan
# 2   kenya  kalobeyei settlement               nan             nan
# 3   kenya  kalobeyei settlement               nan             nan
# 4   kenya  kalobeyei settlement               nan             nan
#
#   connection_period_non_original_subscriber  ...  \
# 0                                       nan  ...
# 1                                       nan  ...
# 2                                       nan  ...
# 3                                       nan  ...
# 4                                       nan  ...
#
#            school_attendance_change school_offering_unable_prior_minigrid  \
# 0  no, we have not noticed a change                         not available
# 1  no, we have not noticed a change                         not available
# 2  no, we have not noticed a change                         not available
# 3  no, we have not noticed a change                         not available
# 4  no, we have not noticed a change                         not available
#
#                           school_performance  \
# 0  no, there has not been a noticable change
# 1  no, there has not been a noticable change
# 2  no, there has not been a noticable change
# 3  no, there has not been a noticable change
# 4  no, there has not been a noticable change
#
#                       minigrid_benefits  \
# 0  increased production and effieciency
# 1                         not available
# 2                         not available
# 3                       increased sales
# 4                         not available
#
#                         minigrid_problems    end_date customerAccountNumber  \
# 0      delayed payment and system updates  2022-07-20                131206
# 1            delayed update after payment  2022-07-20                131231
# 2  initially delayed update after payment  2022-07-20                131542
# 3                         payment problem  2022-07-20                131220
# 4                                     nan  2022-07-20                131485
#
#                      displayName      tariff             community
# 0  shop (jarnot  ndereya nakaya)  commercial  kalobeyei settlement
# 1       shop (lebon wembadiyo m)  commercial  kalobeyei settlement
# 2        shop (abdisalam adam m)  commercial  kalobeyei settlement
# 3            shop (sauda meli m)  commercial  kalobeyei settlement
# 4       shop (kahano ernestre m)  commercial  kalobeyei settlement
#
# [5 rows x 44 columns]

# %%
cols_change = [
'kenya_community',
 'nigeria_community',
 'original_person',
 'connection_period_non_original_subscriber',
 'connection_period',
 'business_type',
 'operation_status',
 'non_renewvia_electrical_sources',
 'kerosene_usage_change',
 'diesel_usage_change',
 'operations_hours_change',
 'business_hours_increase',
 'clean_drinking_water_access',
 'ci_offering_change',
 'workforce_change',
 'workforce_change_female',
 'earnings_change',
 'school_attendance_change',
 'school_performance',
 'tariff'
]

def replace_str(string):
    replace_chars = {'_': ['- ',' (', ' ', '-'],
                    '': ['.)', ',', '/', 'u\n', "'", ".0"]
                    }

    for new, old in replace_chars.items():
        for c in old:
            string = string.replace(c, new)

    return string

for col in list(df.columns):
    df[col] = df[col].apply(lambda x: replace_str(x))
    
df.replace(['nan', '<na>'], np.nan, inplace=True)

df["workforce_change_female"] = df["workforce_change_female"].astype(float).astype('Int64')

df['appliances_addition_count'] = df['appliances_addition_type'].map(lambda x: len(x.split(";")) 
                                                                  if type(x) == str else 0)
# No. of new services offered by clinic
df['health_offering_change_count'] = df['health_offering_change'].map(lambda x: len(x.split(";")) 
                                                                  if type(x) == str else 0)
df['school_performance'].replace('no_there_has_not_been_a_noticable_change',
              'no_there_has_not_been_a_noticeable_change', inplace=True)
df.to_csv("datasets_clean/ci_post_clean.csv")

# %%
cols_focus = [
'renewvia_id',
 'country',
 'community',
 'connection_period_non_original_subscriber',
 'connection_period',
 'business_type',
 'operation_status',
 'non_renewvia_electrical_sources',
 'appliances_addition_type',
 'kerosene_usage_change',
 'diesel_usage_change',
 'operations_hours_change',
 'business_hours_increase',
 'clean_drinking_water_access',
 'ci_offering_change',
 'workforce_change',
 'workforce_change_female',
 'earnings_change',
 'ci_new_offering',
 'health_offering_change',
 'clinic_offering_unable_prior_minigrid',
 'school_attendance_change',
 'school_offering_unable_prior_minigrid',
 'school_performance',
 'end_date',
 'customerAccountNumber',
 'tariff',
 'appliances_addition_count',
 'health_offering_change_count'
]

# Encoding values
df_enc = df[cols_focus].copy()
# mapping missing or mistyped answers
with open('col_answers_mapping.json', 'r') as f:
    col_answers_map = json.load(f)
    
answers = col_answers_map['col_answers_map']
n_col = len(answers)
    
# c_map = []
for i in range(0, n_col):
    col = answers[i]['new_name']
    mapping = answers[i]['mapping']
    
    if col in cols_focus and mapping != {} and col != 'household_business_owners':
        vals = list(mapping.values())
        new_vals = [replace_str(v.lower()) for v in vals]
        col_mapping = dict()
        if "yes" in new_vals and "no" in new_vals:
            col_mapping = {'no': 0, 'yes':1, 
                           'option 1': 0, 'option 2': 1}

        elif any(map(col.__contains__, ["_change", "_improvement"])):

            cats = new_vals
            neutral = ['no', 'same', 'stay', 'not']
            down = ['lost', 'decrease','decreased','decreases',]
            up = ['add', 'better', 'increase',
                    'increased','increases', 'greater']
            for cat in cats:
                cat = str(cat)
                if cat != 'nan':
                    if cat == 'no' or any(map(cat.__contains__, neutral)):
                        col_mapping[cat] = 0
                    elif any(map(cat.__contains__, down)):
                        col_mapping[cat] = -1
                    elif cat == 'yes' or any(map(cat.__contains__, up)):
                        col_mapping[cat] = 1
        else:
            rng = len(new_vals)
            for idx, val in enumerate(new_vals):
                col_mapping[val] = idx+1
                
        df_enc[col].replace(col_mapping, inplace=True)

df_enc.head()
# df_enc.to_csv("datasets_encoded/ci_post_encoded.csv")
# Out:
#   renewvia_id  country             community  \
# 0      131206        2  kalobeyei_settlement
# 1      131231        2  kalobeyei_settlement
# 2      131542        2  kalobeyei_settlement
# 3      131220        2  kalobeyei_settlement
# 4      131485        2  kalobeyei_settlement
#
#    connection_period_non_original_subscriber  connection_period  \
# 0                                        NaN                  4
# 1                                        NaN                  4
# 2                                        NaN                  4
# 3                                        NaN                  4
# 4                                        NaN                  4
#
#    business_type operation_status  non_renewvia_electrical_sources  \
# 0              2              NaN                              1.0
# 1              5              NaN                              1.0
# 2              2              NaN                              1.0
# 3              2              NaN                              1.0
# 4              2              NaN                              1.0
#
#                             appliances_addition_type  kerosene_usage_change  \
# 0  cold_storage__refrigerator_or_freezer;computer...                   -1.0
# 1  cold_storage__refrigerator_or_freezer;exterior...                   -1.0
# 2             cold_storage__refrigerator_or_freezer;                   -1.0
# 3  cold_storage__refrigerator_or_freezer;computer...                    1.0
# 4                          no_additional_appliances;                   -1.0
#
#    ...  health_offering_change  clinic_offering_unable_prior_minigrid  \
# 0  ...          none_of_these;                          not_available
# 1  ...          none_of_these;                          not_available
# 2  ...          none_of_these;                          not_available
# 3  ...          none_of_these;                          not_available
# 4  ...          none_of_these;                          not_available
#
#    school_attendance_change  school_offering_unable_prior_minigrid  \
# 0                       0.0                          not_available
# 1                       0.0                          not_available
# 2                       0.0                          not_available
# 3                       0.0                          not_available
# 4                       0.0                          not_available
#
#    school_performance    end_date  customerAccountNumber      tariff  \
# 0                 3.0  2022_07_20                 131206  commercial
# 1                 3.0  2022_07_20                 131231  commercial
# 2                 3.0  2022_07_20                 131542  commercial
# 3                 3.0  2022_07_20                 131220  commercial
# 4                 3.0  2022_07_20                 131485  commercial
#
#   appliances_addition_count health_offering_change_count
# 0                         4                            2
# 1                         5                            2
# 2                         2                            2
# 3                         6                            2
# 4                         2                            2
#
# [5 rows x 29 columns]
