# %%
import pandas as pd
import numpy as np
import json
import collections

# %%
# Pulled SQL data for each customer id and their tariffs
tariffs = pd.read_csv("customers_tariffs.csv")

# %%
file_names = {
    "initial_commcare": "Commcare INITIAL Survey updated w Renewvia Numbers - Copy.xlsx",
    "initial_msform": "MS Form - INITIAL SURVEY Updated w meter numbers 230216.xlsx",
    "ci_post_commcare": "Commcare - POST Connection - COMMERCIAL & INSTITUTION Connectin Impact Survey.xlsx",
    "ci_post_msform": "MS Form - POST Connection - COMMERCIAL & INSTITUTION Connection Impact Survey.xlsx",
    "hs_post_commcare": "Commcare POST Connection HOUSEHOLD.xlsx",
    "hs_post_msform": "MS Form - POST Connection HOUSEHOLD.xlsx"
    }

datasets = dict()
for name, file in file_names.items():
    datasets[name] = pd.read_excel("datasets_raw/"+file)

# %%
# mapping the columns names
with open('col_rename.json', 'r') as f:
    col_rename_map = json.load(f)
    
name_mapping = dict()
names = col_rename_map['col_rename']
n_col = len(names)
    
for i in range(0, n_col):
    old = names[i]['orignal_name']
    new = names[i]['new_name']
    name_mapping[old] = new

# %%
# mapping missing or mistyped answers
with open('col_answers_mapping.json', 'r') as f:
    col_answers_map = json.load(f)
    
answers = col_answers_map['mapping']
n_col = len(answers)

map_list = list()
for i in range(0, n_col):
    name = answers[i]['col_new_name']
    indv_map = dict()
    # if name in list(df.columns):
    original = answers[i]['original_answers']
    formatted = answers[i]['formatted_answers']
    indv_map =  dict(zip(formatted, original))
    map_list.append(indv_map)
    
print(map_list)
# Out:
# [{}, {}, {}, {'yes': 'Yes', 'no': 'No', 'not_sure': 'Not Sure'}, {'months': '1-3 months', 'copy-1-of-months': '3-6 months', 'copy-2-of-months': '6-12 months', 'copy-3-of-months': '12-24 months', 'copy-4-of-months': '24-36 months', 'over_36_months': 'over 36 months'}, {}, {}, {'nigeria': 'Nigeria', 'kenya': 'Kenya'}, {'akipelai': 'Akipelai', 'oloibiri': 'Oloibiri', 'ozuzu': 'Ozuzu', 'opu': 'Opu', 'balep': 'Balep', 'bendeghe-afi': 'Bendeghe-Afi', 'ekong_anaku': 'Ekong Anaku', 'emeroke': 'Emeroke'}, {'kalobeyei_settlement': 'Kalobeyei Settlement', 'kalobeyei_town': 'Kalobeyei Town', 'ndeda': 'Ndeda', 'ngurunit': 'Ngurunit', 'ringiti': 'Ringiti', 'oyamo': 'Oyamo', 'olkiramatian': 'Olkiramatian', 'lomekwi': 'Lomekwi', 'katiko': 'Katiko', 'locheremoit': 'Locheremoit', 'kangitankori': 'Kangitankori', 'kapelbok': 'Kapelbok', 'lorengelup': 'Lorengelup', 'nakukulas': 'Nakukulas'}, {}, {}, {'male': 'Male', 'female': 'Female'}, {'yes': 'Yes', 'no': 'No'}, {}, {'no_it_is_the_same': 'No, it is the same', 'yes_it_has_increased': 'Yes, it has increased', 'yes_it_has_decreased': 'Yes, it has decreased'}, {}, {}, {'yes_its_increased': "Yes, it's increased", 'yes_its_decreased': "Yes, it's decreased", 'no_it_has_stayed_the_same': 'No, it has stayed the same'}, {}, {'yes_its_increased': "Yes, it's increased", 'yes_its_decreased': "Yes, it's decreased", 'no_its_the_same': "No, it's the same"}, {'yes_its_increased': "Yes, it's increased", 'yes_its_decreased': "Yes, it's decreased", 'no_its_the_same': "No, it's the same"}, {'yes_its_gotten_better': "Yes, it's gotten better", 'yes_its_gotten_worse': "Yes, it's gotten worse", 'no_its_the_same': "No, it's the same"}, {}, {'they_all_attend_school': 'They all attend school', 'household_chores': 'Household chores', 'lacking_money_for_school_fees': 'Lacking money for school fees', 'health_reasons': 'Health reasons', 'childcare': 'Childcare', 'not_old_enough': 'Not old enough', 'too_old': 'Too old', 'other': 'Other'}, {}, {'they_all_attend_school': 'They all attend school', 'household_chores': 'Household chores', 'lacking_money_for_school_fees': 'lacking money for school fees', 'health_reasons': 'Health reasons', 'childcare': 'Childcare', 'not_old_enough': 'Not old enough', 'too_old': 'Too old', 'other': 'Other'}, {}, {'none': 'None', 'adult_male': 'Adult Male', 'adult_female': 'Adult Female'}, {}, {'yes': 'Yes', 'no': 'No'}, {'yes': 'Yes', 'no': 'No', 'maybe': 'Maybe', 'option 1': 'Yes', 'option 2': 'No'}, {'yes': 'Yes ', 'no': 'No'}, {'solar_home_kit': 'solar home kit', 'charcoal': 'charcoal', 'kerosene_lamp': 'kerosene lamp', 'petrol_generator': 'petrol generator', 'diesel_generator': 'diesel generator', 'candles': 'candles', 'minigrid_electricity_renewvia': 'minigrid electricity (Renewvia)', 'other': 'Other'}, {}, {'less_than_2_hours': 'Less than 2 hours', 'between_2_and_5_hours': 'Between 2 and 5 hours', 'between_5_and_8_hours': 'Between 5 and 8 hours', 'more_than_8_hours': 'More than 8 hours'}, {'solar_home_kit': 'solar home kit', 'charcoal': 'charcoal', 'kerosene_lamp': 'kerosene lamp', 'petrol_generator': 'petrol generator', 'diesel_generator': 'diesel generator', 'candles': 'candles', 'minigrid_electricity_renewvia': 'minigrid electricity (Renewvia)', 'other': 'Other'}, {}, {}, {'yes': 'Yes', 'no': 'No'}, {}, {'stovetop': 'stovetop', 'television': 'television', 'computer': 'computer', 'radio': 'radio', 'lights': 'lights', 'fan': 'fan', 'cell_phone_charger': 'cell phone charger', 'other': 'other'}, {}, {'stovetop': 'stovetop', 'television': 'television', 'computer': 'computer', 'radio': 'radio', 'lights': 'lights', 'fan': 'fan', 'cell_phone_charger': 'cell phone charger', 'other': 'other'}, {}, {}, {'battery_powered_flashlighttorch': 'Battery powered (flashlight/torch)', 'electric_source_phone_light_electric_lightbulbs': 'Electric source (phone light, electric lightbulbs)', 'kerosene_source_kerosene_lamps': 'Kerosene source (kerosene lamps)', 'renewvia_minigrid_electricity': 'Renewvia minigrid elect ...

# %%
df = datasets["hs_post_commcare"]
cols = list(df.columns)
cols_clean = [col.replace('\xa0', '') if '\xa0' in col else col for col in cols]
df_rename_dict = dict()
for i in cols_clean:
    if i in list(name_mapping.keys()):
        df_rename_dict[i] = name_mapping[i]

df = df.rename(mapper=df_rename_dict, axis=1)
missing = ['         ', '    ', '   ',
           '******', 'months', 'nan']
df['renewvia_id'] = df['renewvia_id'].apply(lambda x: str(x))
df['renewvia_id'].replace(missing, np.nan, inplace=True)
df['start'] = pd.to_datetime(df['start'])
df['end'] = pd.to_datetime(df['end'])
df['end_date'] = df['end'].dt.date
    
for i in range(0, n_col):
    name = answers[i]['col_new_name']
    if name in list(df.columns):
        vals_original = answers[i]['original_answers']
        vals_formatted = answers[i]['formatted_answers']
        df[name].replace(vals_formatted, vals_original, inplace=True)
    else:
        continue

# %%
for col in list(df.columns):
    cats = df[col].unique()
    if len(cats) < 15:
        print(col, cats)
# Out:
# interviewed_before [nan 'No' 'Yes' 'Not Sure']
# connection_period [nan '12-24 months' '6-12 months' '24-36 months' '3-6 months' '1-3 months']
# country [nan 'Nigeria' 'Kenya']
# nigeria_community [nan 'Ozuzu' 'Emeroke' 'Ekong Anaku' 'Bendeghe-Afi' 'Opu' 'Balep'
#  'Oloibiri']
# kenya_community [nan 'Kalobeyei Settlement']
# gender [nan 'Male' 'Female']
# Has your (or your spouse's) occupation changed since you've been connected to minigrid power? [nan 'no' 'yes']
# Has your household income changed since your  connection to minigrid power? [nan 'yes_it_has_decreased' 'yes_it_has_increased' 'no_it_is_the_same']
# household_headcount_change [nan 'No, it has stayed the same' "Yes, it's increased"
#  "Yes, it's decreased"]
# female_schooling_change [nan "No, it's the same" "Yes, it's increased" "Yes, it's decreased"]
# male_schooling_change [nan "No, it's the same" "Yes, it's increased" "Yes, it's decreased"]
# school_performance_change [nan "Yes, it's gotten better" "No, it's the same"
#  "Yes, it's gotten worse"]
# female_unschooled_reasons [nan 'They all attend school' 'Too old' 'Lacking money for school fees'
#  'Other' 'Not old enough' 'Childcare' 'Health reasons' 'Household chores']
# male_unschooled_reasons [nan 'They all attend school' 'Too old' 'lacking money for school fees'
#  'Other' 'Not old enough' 'Childcare' 'Health reasons' 'Household chores']
# household_business_owners [nan 'None' 'Adult Male' 'Adult Female']
# business_recent [nan 'Yes' 'No']
# business_from_minigrid [nan 'Yes' 'No' 'Maybe']
# business_use_minigrid [nan 'Yes ' 'No']
# power_sources_usage [nan 'Between 2 and 5 hours' 'More than 8 hours' 'Between 5 and 8 hours'
#  'Less than 2 hours']
# power_sources_primary [nan 'minigrid electricity (Renewvia)' 'kerosene lamp' 'petrol generator'
#  'Other' 'solar home kit']
# power_current_sources_explain [nan 'my meter has not been working ever since installation' 'Flashlight']
# electronics_count_change [nan 'No' 'Yes']
# cellphones_count [nan  7. 25.  4.  3.  1.  2.  6.  5.  0.  8. 39.]
# light_primary_sources [nan 'renewvia_minigrid_electricity' 'kerosene_source_kerosene_lamps'
#  'electric_source_phone_light_electric_lightbulbs'
#  'battery_powered_flashlighttorch']
# kerosene_lamp_usage_change [nan "Yes, it's decreased" "No, it's the same" "Yes, it's increased"]
# How many kerosene lamps do you currently use in your household?  (POST minigrid connection) [nan 'none' '2' 'no' '1' '0' 'o']
# kerosene_lamp_usage_time [nan "We don't use a kerosene lamp" 'Less than one hour' '3-5 hours'
#  '1-2 hours' 'Greater than 5 hours']
# kerosene_lamps_cost [nan 'nothing' 'nkes_and_above' 'copy-1-of-nkes' 'copy-2-of-nkes'
#  'copy-3-of-nkes']
# cooking_energy_sources [nan 'Firewood' 'Biomass' 'Other' 'Minigrid electricity (Renewvia)'
#  'Kerosene' 'Charcoal']
# cooking_fuel_collection_time [nan '1-2 hours' 'Less than 1 hour' '3-5 hours' 'No need to collect fuel'
#  'Greater than 5 hours']
# cooking_energy_cost [nan 'nkes' 'copy-4-of-nkes' 'copy-1-of-nkes' 'copy-3-of-nkes'
#  'copy-2-of-nkes' 'nothing_-_we_use_minigrid_power']
# applicances_charging_sources [nan 'Minigrid electricity (Renewvia)' 'Petrol generator'
#  'Diesel generator' 'Other' 'Solar home kit']
# applicances_charging_sources_explain [nan 'Kerosine lamp']
# applicances_charging_cost [nan 'nothing_-_we_use_minigrid_power' 'nkes' 'copy-4-of-nkes'
#  'copy-1-of-nkes' 'copy-3-of-nkes' 'copy-2-of-nkes']
# community_lights [nan 'Yes' 'No']
# home_exterior_lights [nan 'Yes' 'No']
# exterior_lights_minigrid [nan 'Yes' 'No']
# feel_safe_dark [nan 'Very safe' 'Somewhat unsafe' 'Very unsafe' 'Somewhat safe'
#  'Neither safe nor unsafe']
# feel_safe_if_exterior_lights [nan 'Somewhat safe' 'Very safe' 'Very unsafe' 'Somewhat unsafe'
#  'Neither safe nor unsafe']
# feel_unsafe_reasons [nan "I don't feel unsafe" 'Lack of community lighting' 'Potential theft'
#  'Unsafe travel to obtain water, supplies and charging phones' 'Other']
# feel_unsafe_reasons_explain [nan 'i will be safe cause the exterior light itself is security'
#  'Because of news of insecurity'
#  'the ere fear of theft cause the street are dark'
#  'there is always fear at night, since the last kidnaping issue' '0' '.'
#  '*(BAD METER)' 'why do you think that light can make me safe'
#  'it is only God that provide safety' 'Fear of the unkown']
# phone_charge_location [nan 'Home' 'Shop' 'Other' 'Neighbor']
# phone_charge_location_explain [nan 'i dont have a phone'
#  "some times when i put on the generator i charge them at home, but most of the time in my neighbor's place"
#  'some times i charge the phone at my neighbors home' 'Charging Center'
#  'Site' 'Charging center' 'oil mill']
# phone_charge_frequency [nan 'Every 1-2 days' 'Every day' 'Every 4 or more days' 'Every 2-3 days']
# phone_charge_cost [nan 'n_kes_and_above' 'nothing_we_use_minigrid_power' 'copy-3-of-nkes'
#  'nkes' 'copy-2-of-nkes' 'copy-1-of-nkes']
# phone_charge_travel_distance [nan 'No need to travel - charge at home' 'less than 1 km' '2-5km'
#  '1-2 km' 'Greater than 10km']
# water_source [nan 'At home tap' 'Community well or pump'
#  'Dirty water source (pond, contaminated well, etc)'
#  'Clear water source (fresh spring, lake etc)']
# clean_drinking_water [nan 'Yes' 'No']
# clean_drinking_water_source [nan 'Treated / filtered water' 'Clean community source' 'Boiled water'
#  'Bottled water']
# water_collection_travel_distance [nan 'No need to travel - at home water supply' 'less than 1 km' '1-2 km'
#  '2-5 km']
# water_collection_time [nan 'less than 1 hour' '1-2 hours' '2-3 hours' 'greater than 4 hours'
#  '3-4 hours']
# water_collection_responsible [nan 'Whole family - shared responsibility' 'Adult Male' 'Child Female'
#  'Adult Female' 'Child Male']
# avg_person_age_water_collection [nan '15 years or older' '10-12 years old' '12-15 years old'
#  '5-10 years old' 'under 5 years old']
# water_cost [nan 'i_dont_pay_its_free' 'copy-2-of-nkes' 'copy-1-of-nkes' 'nkes']
# clinic_travel_distance [nan 'between 2-3 km' 'between 2-5 km' 'between 1-2 km' 'less than 1 km'
#  'greater than 5 km']
# clinic_electricity_access_minigrid [nan 'No' 'Yes']
# clinic_refrigeration_access [nan 'No' 'Yes']
# better_access_health_minigrid [nan 'Yes' 'No']
# minigrid_access_life_improvement [nan "No, it's the same" 'Yes']

# %%
for df in datasets.values():
    col = ''
    cols = list(df.columns)
    if id_col_names[0] in cols:
        col = id_col_names[0]
    elif id_col_names[1] in cols:
        col = id_col_names[1]
    else:
        print("Couldn't find the Renewvia Account number under the following column names:")
        print(id_col_names)
        break
      
    
    # df.rename()

# %%
# Importing the initial surveys
status = ['Pre-Connection', 'Post-Connection']
initial_commcare = datasets['initial_commcare']
df_merged = initial_commcare.merge(tariffs, 
                                   left_on='What is your Renewvia Minigrid account number?',
                                   right_on='customerAccountNumber', how='left')
df_merged[df_merged['Select your Minigrid Connection Status'] == status[0]]
df_merged.head()
# initial_msform
# # Importing the household post connection 
# ci_post_comncare
# ci_post_msform
# # Importing the household post connection 
# hs_post_comncare
# hs_post_msform
# Out:
#             Start Time       Completed time  \
# 0  2021-09-28 20:21:53  2021-09-28 20:25:03
# 1  2021-10-24 09:49:35  2021-10-24 09:55:40
# 2  2021-10-24 11:09:10  2021-10-24 11:16:09
# 3  2021-10-24 11:16:50  2021-10-24 11:22:41
# 4  2021-10-25 19:43:41  2021-10-25 19:50:12
#
#   Select your Minigrid Connection Status  \
# 0                         pre-connection
# 1                         pre-connection
# 2                         pre-connection
# 3                         pre-connection
# 4                         pre-connection
#
#   If Post-Connection, select how long your have been using the mingrid  \
# 0                                                NaN
# 1                                         3-6_months
# 2                                         3-6_months
# 3                                         3-6_months
# 4                                         3-6_months
#
#   What is your Renewvia Minigrid account number? First Name Last Name  \
# 0                                         501121        cgf      fggg
# 1                                         570063      Agbor   Egbeyip
# 2                                         570028      Agbor       Obi
# 3                                            NaN      Agbor       Obi
# 4                                         570097      Agbor       Eki
#
#    Country Nigeria Community Kenya Community  ...  \
# 0  nigeria          akipelai             NaN  ...
# 1  nigeria             balep             NaN  ...
# 2  nigeria             balep             NaN  ...
# 3  nigeria             balep             NaN  ...
# 4  nigeria             balep             NaN  ...
#
#   How far must you travel to obtain your water supply?  \
# 0                                                NaN
# 1                                     less_than_1_km
# 2                                     less_than_1_km
# 3                                     less_than_1_km
# 4                                                 km
#
#   How long does the water collection process take on a daily basis?  \
# 0                                                NaN
# 1                                   less_than_1_hour
# 2                                                NaN
# 3                                   less_than_1_hour
# 4                                   less_than_1_hour
#
#   Who is mainly responsible for water collection on a daily basis?  \
# 0                                                NaN
# 1                                         child_male
# 2                                         child_male
# 3                                       adult_female
# 4                                       child_female
#
#   What is the average age of the person in charge of water collection?  \
# 0                                                NaN
# 1                                                NaN
# 2                                           or_older
# 3                                           or_older
# 4                                copy-2-of-years_old
#
#   How much do you pay per month for water?  \
# 0                                      NaN
# 1                                     nkes
# 2                      i_dont_pay_its_free
# 3                      i_dont_pay_its_free
# 4                      i_dont_pay_its_free
#
#   Does your household spend time doing any of the following? Select all that apply  \
# 0                                                NaN
# 1                              other_food_processing
# 2                               processing_ugaligari
# 3                              other_food_processing
# 4                                processing_palm_oil
#
#   How close is the nearest Health Center / Clinic  \
# 0                                             NaN
# 1                                  less_than_1_km
# 2                                  less_than_1_km
# 3                                  less_than_1_km
# 4                                  less_than_1_km
#
#    Does your Health Center have access to electricity?  \
# 0                                                NaN
# 1                                                 no
# 2                                                 no
# 3                                                 no
# 4                                                 no
#
#    What hours is the Health Center / Clinic open?  \
# 0                                             NaN
# 1                                        12 hours
# 2                                        12 hours
# 3                                        12 hours
# 4                                        12 hours
#
#    Does your Health Center / Clinic have access to refrigeration?
# 0                                                NaN
# 1                                                 no
# 2                                                 no
# 3                                                 no
# 4                                                 no
#
# [5 rows x 82 columns]

# %%
all_cols = []
for df in datasets.values():
    all_cols.extend(list(df.columns))
    
unique_cols = list(set(all_cols))
print(len(all_cols), len(unique_cols))

cols_sorted = sorted(unique_cols)
cols_sorted
# Out:
# 389 212
# ['Age',
#  'Approximately how many hours a day do you use kerosene lamps?',
#  'Are any household members business owners?',
#  'Are you the original person assigned to this Renewvia ID?\xa0',
#  'Are you the primary provider for your household?',
#  'Are you the primary provider of Household?',
#  'Completed Time',
#  'Completed time',
#  'Completion time',
#  'Country',
#  'Current Source(s) of Power (after mini-grid connection) Select all that apply',
#  'Current Source(s) of Power (before mini-grid connection) Select all that apply',
#  'Current Source(s) of Power (select all that apply)',
#  'Do you feel that having access to minigrid power has made you more safe? Please explain',
#  'Do you feel that having access to minigrid power has made you more safe? Please explain->',
#  'Do you feel that you have better access to health services because of connection to minigrid?',
#  'Do you have a source for clean drinking water?',
#  'Do you have any other sources of electricity other than Renewvia Minigrid?',
#  'Does this business use minigrid power?',
#  'Does your Health Center / Clinic have access to refrigeration?',
#  'Does your Health Center have access to electricity?',
#  'Does your Health Center have access to minigrid electricity?',
#  'Does your community currently have outdoor community lights?',
#  'Does your home have exterior lighting?',
#  'Does your household spend time doing any of the following? Select all that apply',
#  'First Name',
#  'For businesses or shop owners only: Since connection to Renewvia minigrid, have you seen any change in your weekly or monthly earnings?',
#  'For clinics or health services only:  Since connection to Renewvia minigrid, have your health service offerings changed in any of the following ways: (select all that apply).',
#  'For schools only: Since connection to Renewvia minigrid, have you seen a change in overall attendance at school?',
#  'Gender',
#  'Has school performance changed since connection to minigrid?',
#  'Has the number of electronic devices or appliances increased since connection to minigrid?',
#  'Has the number of kerosene lamps in your household changed since connection to minigrid?',
#  'Has the number of people living in your household changed since connection to minigrid power?',
#  'Has there been a change in the number of females in your household who attend school full time since connection to minigrid power?',
#  'Has there been a change in the number of males in your household who attend school FULL TIME since connection to minigrid power?',
#  "Has your (or your spouse's) occupation changed since you've been connected to minigrid power?",
#  'Has your household income changed since your\xa0 connection to minigrid power?',
#  'Have you added any new products or services since connection to Renewvia minigrid?',
#  'Have you added any of the following Electronic Devices or Appliances after you were connected to minigrid (POST connection) Select all that apply',
#  'Have you been interviewed by Renewvia before?',
#  'Have you seen a change in overall school performance?',
#  'How close is the nearest Health Center / Clinic',
#  'How close is the nearest Health Center/Clinic?',
#  'How far must you travel to charge your mobile phone?',
#  'How far must you travel to obtain your water supply?',
#  'How has minigrid power affected the females in your household?',
#  'How long does the cooking fuel collection process take on a daily basis?',
#  'How long does the water collection process take on a daily basis?',
#  'How long have you been connected to the Renewvia Minigrid?',
#  'How many adults?',
#  'How many cell phones does your household have?',
#  'How many electronic devices or appliances do you currently use in the household (POST-connection)?',
#  'How many electronic devices or appliances do you currently use in the household (Pre-connection)?',
#  'How many electronic devices or appliances do you currently use in your household (not including cell phones)?',
#  'How many female children?',
#  'How many hours a day do you use at lease one source of power you checked above',
#  'How many hours a day do you use at least one source of power you checked above?',
#  'How many hours of light per day do you currently have at home?',
#  'How many hours of light per day do you currently have at home? (POST mini-grid connection)',
#  'How many hours of light per day do you currently have at home? (pre mini-grid connection)',
#  'How many kerosene lamps do you currently have in your household?',
#  'How many kerosene lamps do you currently use in your household?  (POST minigrid connection)',
#  'How many kerosene lamps do you currently use in your household?  (before grid connection)',
#  'How many male children?',
#  'How many of your female children attend school?',
#  'How many of your male children attend school?',
#  'How many people live in your household, including yourself?',
#  'How much do you pay monthly for kerosene used only in kerosene lamps?',
#  'How much do you pay per month for water?',
#  'How much do you pay per month to charge your mobile phone?',
#  'How often do you need to charge your mobile phone?',
#  'How safe do you feel outside your home when it is dark?',
#  'How safe would you feel outside your home at nighttime IF you had exterior lights/community lighting?',
#  'How safe would you feel outside your home at nighttime IF you had exterior lights?',
#  'If Post-Connection, select how long your have been using the mingrid',
#  'If any female children do not attend school FULL TIME, please specify why:',
#  'If any female children do not attend school full time, please specifiy why',
#  'If any male children do not attend school FULL TIME, please specify why:',
#  'If any male children do not attend school full time, please specifiy why',
#  'If this business is new, do you consider this new business a result of having access to minigrid power?',
#  'If yes, please explain or list the new occupation:',
#  'If yes, please explain-> or list the new occupation:',
#  'If yes, please explain-> why',
#  'If yes, please explain-> why/how:',
#  'If yes, please explain->:',
#  'If yes, please explain=',
#  'If yes, please explain=/how:',
#  'If yes, please explain=2',
#  'If yes, please tell us why or how it has changed:\xa0',
#  'If yes, what type of business is this?',
#  'If you answered "yes, they have increased" above, by how many hours have they increased?',
#  'If you answered yes to above, please explain*:',
#  'If you answered yes to adding new workers, how many new employees are female?',
#  'If you answered yes to the question above, please explain*:',
#  'If you are NOT the Primary Provider of Household, what is Occupation of Primary Provider?',
#  'If you are NOT the Primary Provider of Household, what is the occupation of Primary Provider?',
#  'If you are NOT the original subscriber to this Renewvia ID, how long have you been using this account for access to Renewvia minigrid power?',
#  'If you have closed operations, please explain* why:',
#  'If you selected "other electronic device" above, please list what it is:',
#  'If you selected "other" in the question above, please explain& (if not, please skip)',
#  'If you selected "other" in the question above, please explain& (if not, please skip)1',
#  'If you selected "other" in the question above, please explain& (if not, please skip)2',
#  'If you selected "other" in the question above, please explain& (if not, please skip)3',
#  'If you selected "other" in the question above, please explain& (if not, please skip)4',
#  'If you selected "other" in the question above, please explain& (if not, please skip)5',
#  'If you selected "other" in the question above, please explain& (if not, please skip)6',
#  'If you selected "other" in the question above, please explain&: (if not, please skip)',
#  'If you selected "other" in the question above, please explain&: (if not, please skip)1',
#  'If you selected "other" in the question above, please explain&: (if not, please skip)2',
#  'If you selected "other" in the question above, please explain->: (if not, please skip)',
#  'If you selected "other" in the question above, please explain->: (if not, please skip)10',
#  'If you selected "other" in the question above, please explain->: (if not, please skip)2',
#  'If you selected "other" in the question above, please explain->: (if not, please skip)3',
#  'If you selected "other" in the question above, please explain->: (if not, please skip)4',
#  'If you selected "other" in the question above, please explain->: (if not, please skip)5',
#  'If you selected "other" in the question above, please explain->: (if not, please skip)6',
#  'If you selected "other" in the question above, please explain->: (if not, please skip)7',
#  'If you selected "other" in the question above, please explain->: (if not, please skip)8',
#  'If you selected "other" in the question above, please explain->: (if not, please skip)9',
#  'If you selected "other" in the question above, please explain= (if not, please skip)',
#  'If you selected "other" in the question above, please explain= (if not, please skip)10',
#  'If you selected "other" in the question above, please explain= (if not, please skip)2',
#  'If you selected "other" in the question above, please explain= (if not, please skip)3',
#  'If you selected "other" in the question above, please explain= (if not, please skip)4',
#  'If you selected "other" in the question above, please explain= (if not, please skip)5',
#  'If you selected "other" in the question above, please explain= (if not, please skip)6',
#  'If you selected "other" in the question above, please explain= (if not, please skip)7',
#  'If you selected "other" in the question above, please explain= (if not, please skip)8',
#  'If you selected "other" in the question above, please explain= (if not, please skip)9',
#  'If you selected "other" in the question above, please explain__: (if not, please skip)',
#  'If you selected "other" in the question above, please explain__: (if not, please skip)10',
#  'If you selected "other" in the question above, please explain__: (if not, please skip)11',
#  'If you selected "other" in the question above, please explain__: (if not, please skip)12',
#  'If you selected "other" in the question above, please explain__: (if not, please skip)2',
#  'If you selected "other" in the question above, please explain__: (if not, please skip)3',
#  'If you selected "other" in the question above, please explain__: (if not, please skip)4',
#  'If you selected "other" in the question above, please explain__: (if not, please skip)5',
#  'If you selected "other" in the question above, please explain__: (if not, please skip)6',
#  'If you selected "other" in the question above, please explain__: (if not, please skip)7',
#  'If you selected "other" in the question above, please explain__: (if not, please skip)8',
#  'If you selected "other" in the question above, please explain__: (if not, please skip)9',
#  'In what way has minigrid power impacted your life or the life of your family members?',
#  'In what way has minigrid power made you or your family more productive?',
#  'Is this business recent (started after connection to minigrid power?)',
#  'Is this business, clinic, school still in operation?',
#  'Is this exterior lighting powered by minigrid?',
#  'Kenya Community',
#  'Kenya community',
#  'Last Name',
#  'Location/Neighborhood Name',
#  'Nigeria Community',
#  'Occupation of Secondary Income Provider of Household',
#  "Please describe any benefits you've seen from having connection to Renewvia minigrid",
#  "Please describe any problems you've experienced from having connection to Renewvia minigrid",
#  'Please select how long your have been using the mingrid.',
#  'Please select your business type',
#  'Select your Minigrid Connection Status',
#  'Since connection to Renewvia mingrid, have you had any change in number of workers/employees at your place of work?',
#  'Since connection to Renewvia minigrid, has the amount of use of diesel changed?\xa0',
#  'Since connection to Renewvia minigrid, has the amount of use of kerosene lanterns changed?\xa0',
#  'Since connection to Renewvia minigrid, has your access to clean drinking water changed at all?',
#  'Since connection to Renewvia minigrid, have your hours of operation changed at all?',
#  'Since connection to Renewvia minigrid, what appliances have you added to your business operations?',
#  'Start Time',
#  'Start time',
#  'Type of employment for Primary Provider',
#  'Types of Electronic Devices or Appliances in Household (POST mini-grid connection) Select all that apply',
#  'Types of Electronic Devices or Appliances in Household (pre-mini-grid connection) Select all that apply',
#  'Types of Electronic Devices or Appliances in Household: Select all that apply',
#  'What are some of the benefits you have experienced because of your access to minigrid?',
#  'What are the ages of your female children?',
#  'What are the ages of your male children?',
#  'What are your current main sources of light?',
#  'What are your main sources of energy for charging appliances (eg phones)? POST - CONNECTION',
#  'What are your main sources of energy for charging appliances (eg phones)? PRE - CONNECTION',
#  'What are your main sources of energy for charging appliances (example phones)?',
#  'What are your main sources of energy for cooking?',
#  'What hours is the Health Center / Clinic open?',
#  'What is approximate monthly cost of energy used strictly for charging appliances?',
#  "What is the Clinic / Hospital able to offer or provide due to connection to Renewvia minigrid that it wasn't able to offer before?",
#  'What is the MAIN reason for signing up for connection to mini-grid?',
#  'What is the MAIN reason for signing up for connection to minigrid?',
#  'What is the SECOND MAIN reason for signing up for connection to mini-grid?',
#  'What is the SECOND MAIN reason for signing up for connection to minigrid?',
#  'What is the approximate monthly cost of energy used strictly for charging appliances?',
#  'What is the approximate monthly cost of energy used strictly for cooking?',
#  'What is the average age of the person in charge of water collection?',
#  'What is the name of your business/school/clinic/religious institution?',
#  'What is the source for clean drinking water?',
#  'What is your Current MAIN Source of Power',
#  'What is your Current MAIN Source of Power?',
#  'What is your Kenya or Nigeria ID Number?',
#  'What is your Renewvia ID Number?',
#  'What is your Renewvia Minigrid account number?',
#  'What is your average monthly household income:',
#  'What is your clean community water source?',
#  'What is your clean water source?',
#  'What is your first name?',
#  'What is your last name?',
#  'What is your main source of energy for cooking?',
#  'What is your occupation?',
#  "What is your school able to offer / accomplish by having electricity that wasn't possible before?",
#  'What is your source of water?',
#  'What makes you feel the most unsafe?',
#  "What services are you able to offer/sell/provide due to connection to Renewvia minigrid that you weren't able to offer prior to connection?",
#  'What types of Electronic Devices or Appliances would you like to add to your Household (pre-mini-grid connection) Select all that apply',
#  'What types of Electronic Devices or Appliances would you like to add to your household? Select all that apply',
#  'Where do you typically charge your mobile phone?',
#  'Who is mainly responsible for cooking fuel collection on a daily basis? Select all that apply',
#  'Who is mainly responsible for water collection on a daily basis?',
#  'Would you say that having access to minigrid power has improved your quality of life?']

# %%
cols_merged_list = list(df_merged.columns)
result = collections.Counter(cols_merged_list) & collections.Counter(cols_sorted)
list(result.elements())
# Out:
# ['Start time',
#  'Completion time',
#  'Select your Minigrid Connection Status',
#  'If Post-Connection, select how long your have been using the mingrid',
#  'What is your Renewvia Minigrid account number?',
#  'What is your Kenya or Nigeria ID Number?',
#  'First Name',
#  'Last Name',
#  'Country',
#  'Nigeria Community',
#  'Kenya Community',
#  'Location/Neighborhood Name',
#  'Age',
#  'Gender',
#  'What is your occupation?',
#  'Are you the primary provider for your household?',
#  'If you are NOT the Primary Provider of Household, what is Occupation of Primary Provider?',
#  'If you selected "other" in the question above, please explain: (if not, please skip)',
#  'Occupation of Secondary Income Provider of Household',
#  'If you selected "other" in the question above, please explain: (if not, please skip)2',
#  'Type of employment for Primary Provider',
#  'What is your average monthly household income:',
#  'How many people live in your household, including yourself?',
#  'How many adults?',
#  'How many female children?',
#  'How many male children?',
#  'What are the ages of your female children?',
#  'What are the ages of your male children?',
#  'How many of your female children attend school?',
#  'If any female children do not attend school full time, please specifiy why',
#  'If you selected "other" in the question above, please explain: (if not, please skip)3',
#  'How many of your male children attend school?',
#  'If any male children do not attend school full time, please specifiy why',
#  'If you selected "other" in the question above, please explain: (if not, please skip)4',
#  'Are any household members business owners?',
#  'What is the MAIN reason for signing up for connection to mini-grid?',
#  'What is the SECOND MAIN reason for signing up for connection to mini-grid?',
#  'Current Source(s) of Power (before mini-grid connection) Select all that apply',
#  'If you selected "other" in the question above, please explain: (if not, please skip)5',
#  'How many hours a day do you use at least one source of power you checked above?',
#  'What is your Current MAIN Source of Power',
#  'If you selected "other" in the question above, please explain: (if not, please skip)6',
#  'How many electronic devices or appliances do you currently use in the household (Pre-connection)?',
#  'How many cell phones does your household have?',
#  'Types of Electronic Devices or Appliances in Household (pre-mini-grid connection) Select all that apply',
#  'If you selected "other" in the question above, please explain: (if not, please skip)7',
#  'What types of Electronic Devices or Appliances would you like to add to your Household (pre-mini-grid connection) Select all that apply',
#  'If you selected "other" in the question above, please explain: (if not, please skip)8',
#  'How many hours of light per day do you currently have at home? (pre mini-grid connection)',
#  'What are your current main sources of light?',
#  'How many kerosene lamps do you currently use in your household?  (before grid connection)',
#  'Approximately how many hours a day do you use kerosene lamps?',
#  'How much do you pay monthly for kerosene used only in kerosene lamps?',
#  'What are your main sources of energy for cooking?',
#  'If you selected "other" in the question above, please explain: (if not, please skip)9',
#  'How long does the cooking fuel collection process take on a daily basis?',
#  'Who is mainly responsible for cooking fuel collection on a daily basis? Select all that apply',
#  'What is the approximate monthly cost of energy used strictly for cooking?',
#  'What are your main sources of energy for charging appliances (eg phones)? PRE - CONNECTION',
#  'If you selected "other" in the question above, please explain: (if not, please skip)10',
#  'What is the approximate monthly cost of energy used strictly for charging appliances?',
#  'How safe do you feel outside your home when it is dark?',
#  'Does your community currently have outdoor community lights?',
#  'Does your home have exterior lighting?',
#  'How safe would you feel outside your home at nighttime IF you had exterior lights?',
#  'What makes you feel the most unsafe?',
#  'If you selected "other" in the question above, please explain: (if not, please skip)11',
#  'Where do you typically charge your mobile phone?',
#  'If you selected "other" in the question above, please explain: (if not, please skip)12',
#  'How often do you need to charge your mobile phone?',
#  'How much do you pay per month to charge your mobile phone?',
#  'How far must you travel to charge your mobile phone?',
#  'What is your source of water?',
#  'Do you have a source for clean drinking water?',
#  'What is the source for clean drinking water?',
#  'What is your clean community water source?',
#  'How far must you travel to obtain your water supply?',
#  'How long does the water collection process take on a daily basis?',
#  'Who is mainly responsible for water collection on a daily basis?',
#  'What is the average age of the person in charge of water collection?',
#  'How much do you pay per month for water?',
#  'Does your household spend time doing any of the following? Select all that apply',
#  'How close is the nearest Health Center/Clinic?',
#  'Does your Health Center have access to electricity?',
#  'What hours is the Health Center / Clinic open?',
#  'Does your Health Center / Clinic have access to refrigeration?']

# %%
df_merged[df_merged[col] == 'Commercial']
# Out:
# Empty DataFrame
# Columns: [Start time, Completion time, Select your Minigrid Connection Status, If Post-Connection, select how long your have been using the mingrid, What is your Renewvia Minigrid account number?, What is your Kenya or Nigeria ID Number?, First Name, Last Name, Country, Nigeria Community, Kenya Community, Location/Neighborhood Name, Age, Gender, What is your occupation?, Are you the primary provider for your household?, If you are NOT the Primary Provider of Household, what is Occupation of Primary Provider?, If you selected "other" in the question above, please explain: (if not, please skip), Occupation of Secondary Income Provider of Household, If you selected "other" in the question above, please explain: (if not, please skip)2, Type of employment for Primary Provider, What is your average monthly household income:, How many people live in your household, including yourself?, How many adults?, How many female children?, How many male children?, What are the ages of your female children?, What are the ages of your male children?, How many of your female children attend school?, If any female children do not attend school full time, please specifiy why, If you selected "other" in the question above, please explain: (if not, please skip)3, How many of your male children attend school?, If any male children do not attend school full time, please specifiy why, If you selected "other" in the question above, please explain: (if not, please skip)4, Are any household members business owners?, What is the MAIN reason for signing up for connection to mini-grid?, What is the SECOND MAIN reason for signing up for connection to mini-grid?, Current Source(s) of Power (before mini-grid connection) Select all that apply, If you selected "other" in the question above, please explain: (if not, please skip)5, How many hours a day do you use at least one source of power you checked above?, What is your Current MAIN Source of Power, If you selected "other" in the question above, please explain: (if not, please skip)6, How many electronic devices or appliances do you currently use in the household (Pre-connection)?, How many cell phones does your household have?, Types of Electronic Devices or Appliances in Household (pre-mini-grid connection) Select all that apply, If you selected "other" in the question above, please explain: (if not, please skip)7, What types of Electronic Devices or Appliances would you like to add to your Household (pre-mini-grid connection) Select all that apply, If you selected "other" in the question above, please explain: (if not, please skip)8, How many hours of light per day do you currently have at home? (pre mini-grid connection), What are your current main sources of light?, How many kerosene lamps do you currently use in your household?  (before grid connection), Approximately how many hours a day do you use kerosene lamps?, How much do you pay monthly for kerosene used only in kerosene lamps?, What are your main sources of energy for cooking?, If you selected "other" in the question above, please explain: (if not, please skip)9, How long does the cooking fuel collection process take on a daily basis?, Who is mainly responsible for cooking fuel collection on a daily basis? Select all that apply, What is the approximate monthly cost of energy used strictly for cooking?, What are your main sources of energy for charging appliances (eg phones)? PRE - CONNECTION, If you selected "other" in the question above, please explain: (if not, please skip)10, What is the approximate monthly cost of energy used strictly for charging appliances?, How safe do you feel outside your home when it is dark?, Does your community currently have outdoor community lights?, Does your home have exterior lighting?, How safe would you feel outside your home at nighttime IF you had exterior lights?, What makes you feel the most unsafe?, If you selected "other" in the question above, please explain: (if not, please skip)11, Where do you typically ...
# Index: []
#
# [0 rows x 88 columns]

# %%
# Isolate columns present in both pre and post survey for paired testing
print(len(df[col].unique()))
initial_ids = list(df[col].unique())
ids_sql_tariffs = list(tariffs['customerAccountNumber'].unique())
result = collections.Counter(initial_ids) & collections.Counter(ids_sql_tariffs)

# # Filter the datasets accordingly
print(len(list(result.elements())))
# df_pre = hs_pre[list(result.elements())]
# df_post = hs_post[list(result.elements())]
# Out:
# 327
# 321
