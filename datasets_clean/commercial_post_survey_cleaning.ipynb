# %%
import pandas as pd
import numpy as np

import category_encoders as ce

# %%
cols = [
"renewvia_id",
"business_type",
"operation_status",
"kerosene_usage_change",
"diesel_usage_change",
"operations_hours_change",
"clean_drinking_water_access",
"new_prod_serv_add",
"workforce_change",
"workforce_change_female",
"weekly_monthly_earnings",
"school_attendance_change",
"school_attendance_performance",
]

cols_non_ord = {"renewvia_id","new_prod_serv_add","business_type"}
cols_ord = [ele for ele in cols if (ele not in cols_non_ord) 
            and (ele != 'workforce_change_female') ]

# %%
# Importing the commecial dataset
df = pd.read_csv("commercial_post_survey_clean.csv", 
                 usecols=cols)
df.replace('nan', np.nan, inplace=True)
df["workforce_change_female"] = df["workforce_change_female"].astype(float).astype('Int64')
    
df.head()
# Out:
#   renewvia_id   business_type operation_status kerosene_usage_change  \
# 0      131206            shop              NaN  yes_it_has_decreased
# 1      131231  other_business              NaN  yes_it_has_decreased
# 2      131542            shop              NaN  yes_it_has_decreased
# 3      131220            shop              NaN  yes_it_has_increased
# 4      131485            shop              NaN  yes_it_has_decreased
#
#     diesel_usage_change  operations_hours_change clean_drinking_water_access  \
# 0  yes_it_has_decreased  yes_they_have_increased        yes_it_has_increased
# 1  yes_it_has_decreased  yes_they_have_increased        yes_it_has_increased
# 2  yes_it_has_decreased  yes_they_have_increased        yes_it_has_increased
# 3  yes_it_has_increased  yes_they_have_increased        yes_it_has_increased
# 4  yes_it_has_decreased  yes_they_have_increased        yes_it_has_increased
#
#   new_prod_serv_add                     workforce_change  \
# 0               yes  no_the_number_has_remained_the_same
# 1               yes            yes_we_have_added_workers
# 2               yes  no_the_number_has_remained_the_same
# 3               yes            yes_we_have_added_workers
# 4                no  no_the_number_has_remained_the_same
#
#    workforce_change_female  weekly_monthly_earnings  \
# 0                     <NA>  yes_they_have_increased
# 1                     <NA>  yes_they_have_increased
# 2                     <NA>  yes_they_have_increased
# 3                     <NA>  yes_they_have_increased
# 4                     <NA>  yes_they_have_increased
#
#           school_attendance_change              school_attendance_performance
# 0  no_we_have_not_noticed_a_change  no_there_has_not_been_a_noticeable_change
# 1  no_we_have_not_noticed_a_change  no_there_has_not_been_a_noticeable_change
# 2  no_we_have_not_noticed_a_change  no_there_has_not_been_a_noticeable_change
# 3  no_we_have_not_noticed_a_change  no_there_has_not_been_a_noticeable_change
# 4  no_we_have_not_noticed_a_change  no_there_has_not_been_a_noticeable_change

# %%
# Creating the mapping for each categroical variable with ordinality
cats_ord_map = list()
for col in cols_ord:
    val_ord = dict()
    cats = list(df[col].unique())
    for cat in cats:
        cat = str(cat)
        if cat != 'nan':
            if any(map(cat.__contains__, ['no', 'same'])):
                val_ord[cat] = 0
            elif any(map(cat.__contains__, ['lost', 'decrease'])):
                val_ord[cat] = -1
            elif any(map(cat.__contains__, ['still', 'add', 
                                            'better', 'increase',
                                           'greater'])):
                val_ord[cat] = 1

    cats_ord_map.append({"col":col, "mapping": val_ord})

        

#Binary Encoding
enc_bin = ce.BinaryEncoder(cols =["new_prod_serv_add"], 
                            handle_unknown="return_nan",
                            handle_missing="return_nan", 
                            return_df=True)
df = enc_bin.fit_transform(df)
# OneHot Encoding
# enc_hot = ce.OneHotEncoder(cols =["business_type"], 
#                             handle_unknown="return_nan",
#                             handle_missing="return_nan",
#                             use_cat_names=True,
#                             return_df=True)
# df = enc_hot.fit_transform(df)

#Ordinal Encoding
enc_ord = ce.OrdinalEncoder(mapping=cats_ord_map, 
                            handle_unknown="return_nan",
                            handle_missing="return_nan",
                            return_df=True)

df = enc_ord.fit_transform(df)

# df.head()
df.to_csv("commercial_post_survey_encoded")
